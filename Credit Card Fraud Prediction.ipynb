# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
card_data = pd.read_csv('creditcard.csv')

# %%
card_data.shape
# Out:
# (284807, 31)

# %%
card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
card_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#distribution of legal transection and fraud transaction
card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # This data is highly unbalanced

# %% [markdown]
# O represent normal transection
# 1 represent fraud transection

# %%
#seperating the data for analysis
legal = card_data[card_data.Class==0]
#if class value is O then entire row is stored in legal variable
fraud = card_data[card_data.Class==1]
#if class value is 1 then entire row is stored in fraud variable

# %%
print(legal.shape,fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
#statistical measure of the data
legal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare tthe values for both transections
card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Under Sampling
# Bulit a sample data containing the similar distribution of
# normal tansectionand fraud transection

# %% [markdown]
# number of fraud transection is 492

# %%
legal_sample = legal.sample(n=492)

# %%
print(legal_sample.shape,fraud.shape)
# Out:
# (492, 31) (492, 31)

# %%
#concatenating two dataframe
new_data = pd.concat([legal_sample,fraud],axis=0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 216954  140703.0 -0.572111  1.045940 -0.920343  0.464597  0.949915 -0.263172
# 206932  136447.0 -0.319293  0.458531 -2.013463 -3.556483  2.649828  2.783704
# 200547  133477.0 -1.672121  1.799935  0.111227 -1.209206  0.952041 -0.679089
# 182286  125333.0 -0.949787 -0.112468  1.421163 -1.041502 -2.257213  1.532399
# 235411  148378.0 -0.305965  0.921026  0.293663 -0.816886  1.044253 -0.725125
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 216954  0.579305  0.264533 -0.088323  ... -0.026125 -0.306197  0.171842
# 206932  0.297962  1.110863  0.427818  ...  0.050986  0.072217  0.019211
# 200547  1.296999 -0.603263  1.268802  ... -0.082147  0.431242 -0.613914
# 182286 -1.725655 -0.688731  0.114811  ...  2.000571  1.081017  0.054134
# 235411  1.146116 -0.231918 -0.337622  ... -0.246557 -0.510578 -0.054856
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96935.579268 -0.124515 -0.026549 -0.104471 -0.098305  0.087815
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.027968 -0.000198  0.012821  0.009348  ...  0.025081 -0.021536
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.008459 -0.033927  0.032835 -0.026287 -0.027867  0.012187 -0.032717
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       89.503557
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into target and features

# %%
data = new_data.drop(columns='Class',axis=1)
label=new_data['Class']

# %%
data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 216954  140703.0 -0.572111  1.045940 -0.920343  0.464597  0.949915 -0.263172
# 206932  136447.0 -0.319293  0.458531 -2.013463 -3.556483  2.649828  2.783704
# 200547  133477.0 -1.672121  1.799935  0.111227 -1.209206  0.952041 -0.679089
# 182286  125333.0 -0.949787 -0.112468  1.421163 -1.041502 -2.257213  1.532399
# 235411  148378.0 -0.305965  0.921026  0.293663 -0.816886  1.044253 -0.725125
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 216954  0.579305  0.264533 -0.088323  ... -0.415853 -0.026125 -0.306197
# 206932  0.297962  1.110863  0.427818  ... -0.192394  0.050986  0.072217
# 200547  1.296999 -0.603263  1.268802  ...  0.719742 -0.082147  0.431242
# 182286 -1.725655 -0.688731  0.114811  ... -0.414702  2.000571  1.081017
# 235411  1.146116 -0.231918 -0.337622  ...  0.140413 -0.246557 -0.510578
#
# ...

# %%
X_train,X_test,Y_train,Y_test = train_test_split(data,label,test_size=.2,stratify=label ,random_state=2)

# %%
print(data.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
model = LogisticRegression()

# %%
#training the data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print(training_data_accuracy)
# Out:
# 0.940279542566709

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

print(test_data_accuracy)
# Out:
# 0.949238578680203

# %% [markdown]
# # Predictive System

# %%
input_data = (10,1.249998742053,-1.22163680921816,0.383930151282291,-1.23489868766892,-1.48541947377961,-0.753230164566149,-0.689404975426345,-0.227487227519552,-2.09401057344842,1.32372927445937,0.227666231237246,-0.242681998944186,1.20541680770748,-0.317630527025074,0.725674990179153,-0.815612186027305,0.873936447614439,-0.847788598847099,-0.683192626267037,-0.102755941505071,-0.231809239223849,-0.483285330117712,0.0846676908596583,0.392830885335013,0.161134553588505,-0.354990039673962,0.0264155490776107,0.0424220887282304,121.5)

#changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#Standardize the input data
#standard_data = model.transform(input_data_reshaped)

#print(standard_data)

prediction = model.predict(input_data_reshaped)

if prediction == 0:
    print('Normal Transection')
else:
    print('Fraud Transection')
# Out:
# Normal Transection
# C:\Users\hwale\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
